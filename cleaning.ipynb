# %%
import pandas as pd
import numpy as np
import requests as req
from bs4 import BeautifulSoup
from random import randint
import random
from time import sleep
import re
import os

# %%
dir = "Non Used\Segunda Divisão Austriaca" # insert league folder
for f in os.listdir(dir):
	table = pd.read_csv(dir + "/" + f)
	table = table.set_index("rank").drop("Unnamed: 0", axis=1).reset_index()
	table.iloc[0,2]
	if (table.iloc[0,2] == table.iloc[0,9] * 2 -2):
		if(os.path.exists(dir + "/Good_tables")):
			table.to_csv(dir + "/Good_tables/" + f)
		else:
			os.mkdir(dir + "/Good_tables")
			table.to_csv(dir + "/Good_tables/" + f)
	else:
		if(os.path.exists(dir + "/Bad_tables")):
			table.to_csv(dir + "/Bad_tables/" + f)
		else:
			os.mkdir(dir + "/Bad_tables")
			table.to_csv(dir + "/Bad_tables/" + f)

# %%
dir = "Data to clean" # insert league folder
total_count = 0
count = 0
for f in os.listdir(dir):
	for i in os.listdir(dir + "/" + f):
		count += 1
	total_count += count
	count = 0
print(total_count)
# Out:
# 81

# %%
def clean_playoffs(file):
	table = pd.read_csv(file)
	teams_to_del = table.isna().sum()[3]
	temp_name_list = table["team_name"][teams_to_del:].reset_index()
	temp_name_list.dropna(inplace=True)
	table = table[:-teams_to_del].drop("Unnamed: 0", axis=1).reset_index()
	table["team_name"] = temp_name_list["team_name"]
	table["team_n"] = len(table)
	table["rank"] = np.arange(1, len(table) + 1)
	table.drop("index", axis=1, inplace=True)
	table.to_csv(file.replace(".csv", "_clean.csv"))
	display(table)
	return table

# %%
name = "League Two Bad_tables"
dir = "Data to clean/" + name
for f in os.listdir(dir):
		print(f)
		clean_playoffs(dir + "/" + f)
# Out:
# 107516.csv
#     rank            team_name    GP     W     D     L    GF    GA     P  \
# 0      1   Accrington Stanley  46.0  29.0   6.0  11.0  76.0  46.0  93.0
# 1      2           Luton Town  46.0  25.0  13.0   8.0  94.0  46.0  88.0
# 2      3    Wycombe Wanderers  46.0  24.0  12.0  10.0  79.0  60.0  84.0
# 3      4          Exeter City  46.0  24.0   8.0  14.0  64.0  54.0  80.0
# 4      5         Notts County  46.0  21.0  14.0  11.0  71.0  48.0  77.0
# 5      6        Coventry City  46.0  22.0   9.0  15.0  64.0  47.0  75.0
# 6      7         Lincoln City  46.0  20.0  15.0  11.0  64.0  48.0  75.0
# 7      8       Mansfield Town  46.0  18.0  18.0  10.0  67.0  52.0  72.0
# 8      9         Swindon Town  46.0  20.0   8.0  18.0  67.0  65.0  68.0
# 9     10      Carlisle United  46.0  17.0  16.0  13.0  62.0  54.0  67.0
# 10    11       Newport County  46.0  16.0  16.0  14.0  56.0  58.0  64.0
# 11    12     Cambridge United  46.0  17.0  13.0  16.0  56.0  60.0  64.0
# ...
